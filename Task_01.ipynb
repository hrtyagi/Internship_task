# %% [markdown]
# # Importing Required Libraries

# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_excel("cutoff_excel.xlsx")

pd.set_option('max_colwidth',1500)
data
# Out:
#                                                                                                                                                                                                                                                                                 Unnamed: 0  \
# 0                                                                                                   1002 - Government College of Engineering, Amravati\n100219110 - Civil Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 1                                                                                                                                                                                                                                                                                      NaN
# 2                                                                                                                                                                                                                                                                                        I
# 3                                                                                                                                        100224210 - Computer Science and Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 4                                                                                                                                                                                                                                                                                      NaN
# ...                                                                                                                                                                                                                                                                                    ...
# 19048                                                                                               693861210F - Mechanical Engineering\nStatus:    Home University : Dr. Babasaheb Ambedkar Technological University,Lonere\nHome University Seats Allotted to Home University Candidates
# 19049                                                                                                                                                                                                                                                                                  NaN
# 19050                                                                                                                                                                                                                                                                                    I
# 19051  Legends: Starting character G-General, L-Ladies, End character H-Home University, O-Other than Home University,S-State Level, AI- All India Seat\n. Maharashtra State Seats - Cut Off Indicates Maharashtra State General Merit No.; Figures in bracket Indicates Merit Percentile.
# 19052                                                                                                                                                                                                                                                                                  NaN
#
#                 Unnamed: 1 Unnamed: 2           Unnamed: 3 Unnamed: 4  \
# 0                      NaN        NaN                  NaN        NaN
# 1                   GOPENS        NaN                 GSCS        NaN
# 2       9698\n(95.4813409)        NaN  16599\n(91.9454241)        NaN
# 3                      NaN        NaN                  NaN        NaN
# 4                   GOPENS        NaN                 GSCS        NaN
# ...                    ...        ...                  ...        ...
# 19048                  NaN        NaN                  NaN        NaN
# 19049               LOPENH        NaN                  NaN        NaN
# 19050  69650\n(24.0098347)        NaN                  NaN        NaN
# 19051                  NaN        NaN                  NaN        NaN
# 19052                  NaN        NaN                  NaN        NaN
#
#                 Unnamed: 5 Unnamed: 6           Unnamed: 7  Unnamed: 8  \
# 0                      NaN        NaN                  NaN         NaN
# 1                     GSTS        NaN                 GVJS         NaN
# 2      28642\n(83.7510773)        NaN  11127\n(94.7976941)         NaN
# 3                      NaN        NaN                  NaN         NaN
# 4                     GSTS        NaN                 GVJS         NaN
# ...                    ...        ...                  ...         ...
# 19048                  NaN        NaN                  NaN         NaN
# 19049                  NaN        NaN                  NaN         NaN
# 19050                  NaN        NaN                  NaN         NaN
# 19051                  NaN        NaN                  NaN         NaN
# 19052                  NaN        NaN                  NaN         NaN
#
#                 Unnamed: 9  ...          Unnamed: 18          Unnamed: 19  \
# 0                      NaN  ...                  NaN                  NaN
# 1                    GNT2S  ...                LOBCS               LSEBCS
# 2      19612\n(90.2192884)  ...  11580\n(94.5663116)  22466\n(88.4395617)
# 3                      NaN  ...                  NaN                  NaN
# 4                    GNT1S  ...                LNT2S                LOBCS
# ...                    ...  ...                  ...                  ...
# 19048                  NaN  ...                  NaN                  NaN
# 19049                  NaN  ...                  NaN                  NaN
# 19050                  NaN  ...                  NaN                  NaN
# 19051                  NaN  ...                  NaN                  NaN
# 19052                  NaN  ...                  NaN                  NaN
#
#                Unnamed: 20          Unnamed: 21          Unnamed: 22  \
# 0                      NaN                  NaN                  NaN
# 1                 PWDOPENS             DEFOPENS                  EWS
# 2      29243\n(83.2108225)  15132\n(92.7416843)  23463\n(87.7548286)
# 3                      NaN                  NaN                  NaN
# 4                   LSEBCS             PWDOPENS               PWDSCS
# ...                    ...                  ...                  ...
# 19048                  NaN                  NaN                  NaN
# 19049                  NaN                  NaN                  NaN
# 19050                  NaN                  NaN                  NaN
# 19051                  NaN                  NaN                  NaN
# 19052                  NaN                  NaN                  NaN
#
#               Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27
# 0                     NaN         NaN         NaN         NaN         NaN
# 1                    TFWS         NaN         NaN         NaN         NaN
# 2      5336\n(97.5366265)         NaN         NaN         NaN         NaN
# 3                     NaN         NaN         NaN         NaN         NaN
# 4                 PWDOBCS         NaN    DEFOPENS         EWS        TFWS
# ...                   ...         ...         ...         ...         ...
# 19048                 NaN         NaN         NaN         NaN         NaN
# 19049                 NaN         NaN         NaN         NaN         NaN
# 19050                 NaN         NaN         NaN         NaN         NaN
# 19051                 NaN         NaN         NaN         NaN         NaN
# 19052                 NaN         NaN         NaN         NaN         NaN
#
# [19053 rows x 28 columns]

# %%
print(data['Unnamed: 2'].value_counts(dropna=False))
print("**"*50)
print(data['Unnamed: 4'].value_counts(dropna=False))
print("**"*50)
print(data['Unnamed: 6'].value_counts(dropna=False))
# Out:
# NaN                   19046
# EWS                       2
# -99.3677716               1
# 321\n(99.8207600)         1
# 1268\n(99.3670474)        1
# 1266                      1
# TFWS                      1
# Name: Unnamed: 2, dtype: int64
# ****************************************************************************************************
# NaN                    19049
# ORPHAN                     2
# 64674\n(30.3715881)        1
# 54715\n(48.0511721)        1
# Name: Unnamed: 4, dtype: int64
# ****************************************************************************************************
# NaN                  19049
# TFWS                     2
# 247\n(99.8580564)        1
# 25\n(99.9887749)         1
# Name: Unnamed: 6, dtype: int64

# %%
for i in range(2,24,2):
    col_unwant='Unnamed: '+str(i)
    data.drop(col_unwant,axis=1,inplace=True)
#data.drop('Unnamed: 2',axis=1,inplace=True)
#data.drop('Unnamed: 4',axis=1,inplace=True)
#data.drop('Unnamed: 6',axis=1,inplace=True)
#data.drop('Unnamed: 8',axis=1,inplace=True)

# %% [markdown]
# # Changing column_name
# - for simplicity

# %%
cols = []
count = 1
for column in data.columns:
    cols.append(count)
    count+=1
    continue
    
data.columns = cols

# %%
data
# Out:
#                                                                                                                                                                                                                                                                                         1   \
# 0                                                                                                   1002 - Government College of Engineering, Amravati\n100219110 - Civil Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 1                                                                                                                                                                                                                                                                                      NaN
# 2                                                                                                                                                                                                                                                                                        I
# 3                                                                                                                                        100224210 - Computer Science and Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 4                                                                                                                                                                                                                                                                                      NaN
# ...                                                                                                                                                                                                                                                                                    ...
# 19048                                                                                               693861210F - Mechanical Engineering\nStatus:    Home University : Dr. Babasaheb Ambedkar Technological University,Lonere\nHome University Seats Allotted to Home University Candidates
# 19049                                                                                                                                                                                                                                                                                  NaN
# 19050                                                                                                                                                                                                                                                                                    I
# 19051  Legends: Starting character G-General, L-Ladies, End character H-Home University, O-Other than Home University,S-State Level, AI- All India Seat\n. Maharashtra State Seats - Cut Off Indicates Maharashtra State General Merit No.; Figures in bracket Indicates Merit Percentile.
data.drop(extra_row_02,inplace=True)

extra_row_03=data.index[data[1]=='Other Than Home University Seats Allotted to Other Than Home University Candidates'].tolist()
data.drop(extra_row_03,inplace=True)

extra_row_04=data.index[data[1]=='Home University Seats Allotted to Other Than Home University Candidates'].tolist()
data.drop(extra_row_04,inplace=True)

extra_row_05=data.index[data[1]=='State Level'].tolist()
data.drop(extra_row_05,inplace=True)

extra_row_06=data.index[data[1]=='Other Than Home University Seats Allotted to Home University Candidates'].tolist()
data.drop(extra_row_06,inplace=True)

extra_row07=data.index[data[1]=='TFWS'].tolist()
data.drop(extra_row_07,inplace=True)

# %% [markdown]
# ## Fill Na values with " "

# %%
data.fillna(" ",inplace=True)

# %% [markdown]
# ## Removing Blank rows

# %%
idx_col_01_blanks=data.index[data[1]==" "].tolist()
idx_col_02_blanks=data.index[data[2]==" "].tolist()
idx_col_03_blanks=data.index[data[3]==" "].tolist()

l1=[]
blank_rows=[]
for i in idx_col_01_blanks:
    if i in idx_col_02_blanks:
        l1.append(i)
for i in l1:
    if i in idx_col_03_blanks:
        blank_rows.append(i)
        
data.drop(blank_rows,inplace=True)

# %%
data
# Out:
#                                                                                                                                                                                            1   \
# 0      1002 - Government College of Engineering, Amravati\n100219110 - Civil Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 1
# 2                                                                                                                                                                                           I
# 3                                           100224210 - Computer Science and Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 4
# ...                                                                                                                                                                                       ...
# 19046
# 19047                                                                                                                                                                                       I
# 19048  693861210F - Mechanical Engineering\nStatus:    Home University : Dr. Babasaheb Ambedkar Technological University,Lonere\nHome University Seats Allotted to Home University Candidates
# 19049
# 19050                                                                                                                                                                                       I
#
#                         2                    3                    4   \
# 0
# 1                   GOPENS                 GSCS                 GSTS
# 2       9698\n(95.4813409)  16599\n(91.9454241)  28642\n(83.7510773)
# 3
# 4                   GOPENS                 GSCS                 GSTS
# ...                    ...                  ...                  ...
# 19046               LOPENH
# 19047  73173\n(20.5318540)
# 19048
# 19049               LOPENH
# 19050  69650\n(24.0098347)
#
#                         5                    6                    7   \
# 0
# 1                     GVJS                GNT2S                GOBCS
# 2      11127\n(94.7976941)  19612\n(90.2192884)  11430\n(94.6416286)
# 3
# 4                     GVJS                GNT1S                GNT3S
# ...                    ...                  ...                  ...
# 19046
# 19047
# 19048
# 19049
# 19050
#
#                        8                    9                    10  \
# 0
# 1                  LOPENS                 LSTS                LNT2S
# 2      8428\n(96.0918433)  40288\n(71.0905760)  11019\n(94.8483883)
# 3
# 4                  GSEBCS                 LSCS                LNT1S
# ...                   ...                  ...                  ...
# 19046
# 19047
# 19048
# 19049
# 19050
#
#                         11                   12                  13 14  \
# 0
# 1                   LSEBCS             DEFOPENS                TFWS
# 2      22466\n(88.4395617)  15132\n(92.7416843)  5336\n(97.5366265)
# 3
# 4                    LOBCS             PWDOPENS             PWDOBCS
# ...                    ...                  ...                 ... ..
# 19046
# 19047
# 19048
# 19049
# 19050
#
#              15   16    17
# 0
# 1
# 2
# 3
# 4      DEFOPENS  EWS  TFWS
# ...         ...  ...   ...
# 19046
# 19047
# 19048
# 19049
# 19050
#
# [12113 rows x 17 columns]

# %%
data.reset_index(drop=True,inplace=True)

# %% [markdown]
# # Task

# %%
data_01=data.iloc[:,:2]

# %%
data_01.columns = ['text',"score"]

# %%
data_01
# Out:
#                                                                                                                                                                                          text  \
# 0      1002 - Government College of Engineering, Amravati\n100219110 - Civil Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 1
# 2                                                                                                                                                                                           I
# 3                                           100224210 - Computer Science and Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 4
# ...                                                                                                                                                                                       ...
# 12108
# 12109                                                                                                                                                                                       I
# 12110  693861210F - Mechanical Engineering\nStatus:    Home University : Dr. Babasaheb Ambedkar Technological University,Lonere\nHome University Seats Allotted to Home University Candidates
# 12111
# 12112                                                                                                                                                                                       I
#
#                      score
# 0
# 1                   GOPENS
# 2       9698\n(95.4813409)
# 3
# 4                   GOPENS
# ...                    ...
# 12108               LOPENH
# 12109  73173\n(20.5318540)
# 12110
# 12111               LOPENH
# 12112  69650\n(24.0098347)
#
# [12113 rows x 2 columns]

# %%
data_01.head()
# Out:
#                                                                                                                                                                                      text  \
# 0  1002 - Government College of Engineering, Amravati\n100219110 - Civil Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 1
# 2                                                                                                                                                                                       I
# 3                                       100224210 - Computer Science and Engineering\nStatus:    Government Autonomous Home University : Sant Gadge Baba Amravati University\nState Level
# 4
#
#                 score
# 0
# 1              GOPENS
# 2  9698\n(95.4813409)
# 3
# 4              GOPENS

# %% [markdown]
# # Arranging data into interpretable form

# %%
final_dict = {}
import re

for i in range(0,data_01.shape[0]):
    try:
        m = data_01.iloc[i:i+3]
        m = m.values

        text = " ".join([str(k) for k in m[:,0]]).strip()
        values = " ".join(m[:,1]).strip()

#        print(text)

        text = text.split("\n")
        vals = values.split("\n")
    
        final_dict[i] =  {}
    
        if len(text) == 4:
            final_dict[i]['College_code'] = re.findall("[0-9]+",text[0])[0]
            final_dict[i]['College_name'] = " ".join(re.findall("[a-zA-Z,]+",text[0]))
            final_dict[i]['Subject_code'] = re.findall("[0-9]+",text[1])[0]
        
            final_dict[i]['Subject_name'] = " ".join(re.findall("[a-zA-Z,]+",text[1]))
            
            final_dict[i]['Home University'] = " ".join(re.findall("[a-zA-Z,]+",text[2].split("Home University")[1]))


            final_dict[i]['Cateogry'] = re.findall("[a-zA-Z]+",vals[0])[0]
            final_dict[i]['Rank'] = re.findall("[0-9]+",vals[0])[0]
            final_dict[i]['Score'] = re.findall("([0-9.]+)",vals[1])[0]
    
    
        elif len(text) == 3:
#             print(text)
                final_dict[i]['College_code'] = np.nan
                final_dict[i]['College_name'] = np.nan

                final_dict[i]['Subject_code'] = re.findall("[0-9]+",text[0])[0]
                final_dict[i]['Subject_name'] = " ".join(re.findall("[a-zA-Z,]+",text[0]))

                final_dict[i]['Home University'] = " ".join(re.findall("[a-zA-Z,]+",text[1].split("Home University")[1]))


                final_dict[i]['Cateogry'] = re.findall("[a-zA-Z]+",vals[0])[0]
                final_dict[i]['Rank'] = re.findall("[0-9]+",vals[0])[0]
                final_dict[i]['Score'] = re.findall("([0-9.]+)",vals[1])[0]
        else:
            pass
    except Exception as e:
        pass

# %%
data_02 = pd.DataFrame.from_records(final_dict).T.dropna(axis=0,how="all")
data_02 = data_02.drop_duplicates(['Subject_code','Subject_name'])

# %%
data_02
# Out:
#       College_code  \
# 0             1002
# 1              NaN
# 3              NaN
# 4              NaN
# 6              NaN
# ...            ...
# 12102          NaN
# 12104          NaN
# 12105         6938
# 12108          NaN
# 12110          NaN
#
#                                                      College_name  \
# 0                     Government College of Engineering, Amravati
# 1                                                             NaN
# 3                                                             NaN
# 4                                                             NaN
# 6                                                             NaN
# ...                                                           ...
# 12102                                                         NaN
# 12104                                                         NaN
# 12105  I Shree Siddheshwar Women s College Of Engineering Solapur
# 12108                                                         NaN
# 12110                                                         NaN
#
#       Subject_code                              Subject_name  \
# 0        100219110                         Civil Engineering
# 1        100224210        I Computer Science and Engineering
# 3        100224210          Computer Science and Engineering
# 4        100224610                  I Information Technology
# 6        100224610                    Information Technology
# ...            ...                                       ...
# 12102    693829310                I F Electrical Engineering
# 12104    693829310                  F Electrical Engineering
# 12105    693837210  F Electronics and Telecommunication Engg
# 12108    693861210                I F Mechanical Engineering
# 12110    693861210                  F Mechanical Engineering
#
#                                              Home University Cateogry   Rank  \
# 0                        Sant Gadge Baba Amravati University   GOPENS   9698
# 1                        Sant Gadge Baba Amravati University   GOPENS   9698
# 3                        Sant Gadge Baba Amravati University   GOPENS   3389
# 4                        Sant Gadge Baba Amravati University   GOPENS   3389
# 6                        Sant Gadge Baba Amravati University   GOPENS   6384
# ...                                                      ...      ...    ...
# 12102  Dr Babasaheb Ambedkar Technological University,Lonere      EWS  86690
# 12104  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  50310
# 12105  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  50310
# 12108  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  73173
# 12110  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  69650
#
#             Score
# 0      95.4813409
# 1      95.4813409
# 3      98.4034964
# 4      98.4034964
# 6      97.0514111
# ...           ...
# 12102   1.1949335
# 12104  55.8309133
# 12105  55.8309133
# 12108  20.5318540
# 12110  24.0098347
#
# [2085 rows x 8 columns]

# %%
data_02.fillna(method="bfill").fillna(method='ffill')
# Out:
#       College_code  \
# 0             1002
# 1             1002
# 3             1002
# 4             1002
# 6             1002
# ...            ...
# 12102         6938
# 12104         6938
# 12105         6938
# 12108         6938
# 12110         6938
#
#                                                      College_name  \
# 0                     Government College of Engineering, Amravati
# 1                   I Government College of Engineering, Amravati
# 3                   I Government College of Engineering, Amravati
# 4                   I Government College of Engineering, Amravati
# 6                   I Government College of Engineering, Amravati
# ...                                                           ...
# 12102  I Shree Siddheshwar Women s College Of Engineering Solapur
# 12104  I Shree Siddheshwar Women s College Of Engineering Solapur
# 12105  I Shree Siddheshwar Women s College Of Engineering Solapur
# 12108  I Shree Siddheshwar Women s College Of Engineering Solapur
# 12110  I Shree Siddheshwar Women s College Of Engineering Solapur
#
#       Subject_code                              Subject_name  \
# 0        100219110                         Civil Engineering
# 1        100224210        I Computer Science and Engineering
# 3        100224210          Computer Science and Engineering
# 4        100224610                  I Information Technology
# 6        100224610                    Information Technology
# ...            ...                                       ...
# 12102    693829310                I F Electrical Engineering
# 12104    693829310                  F Electrical Engineering
# 12105    693837210  F Electronics and Telecommunication Engg
# 12108    693861210                I F Mechanical Engineering
# 12110    693861210                  F Mechanical Engineering
#
#                                              Home University Cateogry   Rank  \
# 0                        Sant Gadge Baba Amravati University   GOPENS   9698
# 1                        Sant Gadge Baba Amravati University   GOPENS   9698
# 3                        Sant Gadge Baba Amravati University   GOPENS   3389
# 4                        Sant Gadge Baba Amravati University   GOPENS   3389
# 6                        Sant Gadge Baba Amravati University   GOPENS   6384
# ...                                                      ...      ...    ...
# 12102  Dr Babasaheb Ambedkar Technological University,Lonere      EWS  86690
# 12104  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  50310
# 12105  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  50310
# 12108  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  73173
# 12110  Dr Babasaheb Ambedkar Technological University,Lonere   LOPENH  69650
#
#             Score
# 0      95.4813409
# 1      95.4813409
# 3      98.4034964
# 4      98.4034964
# 6      97.0514111
# ...           ...
# 12102   1.1949335
# 12104  55.8309133
# 12105  55.8309133
# 12108  20.5318540
# 12110  24.0098347
#
# [2085 rows x 8 columns]

# %%
data_02.reset_index(drop=True,inplace=True)

# %% [markdown]
# ## Extracting all the colleges which comes under Savitribai Phule Pune University

# %%
not_savitribai_clgs=data_02.index[data_02["Home University"]!="Savitribai Phule Pune University"].tolist()
print(len(not_savitribai_clgs))
data_02.drop(not_savitribai_clgs,inplace=True)
# Out:
# 1457

# %% [markdown]
# # Extracting data of civil engineering

# %%
not_civil=data_02.index[data_02["Subject_name"]!="Civil Engineering"].tolist()
print(len(not_civil))
data_02.drop(not_civil,inplace=True)
# Out:
# 549

# %%
data_02.reset_index(drop=True,inplace=True)

# %%
data_02
# Out:
#    College_code  \
# 0          5108
# 1          5109
# 2          5121
# 3          5121
# 4          5124
# ..          ...
# 74         6795
# 75         6796
# 76         6802
# 77         6822
# 78         6834
#
#                                                                                                                 College_name  \
# 0   I Nashik District Maratha Vidya Prasarak Samaj s Karmaveer Adv Babaurao Ganpatrao Thakare College of Engineering, Nashik
# 1                                I Sandip Foundation, Sandip Institute of Technology and Research Centre, Mahiravani, Nashik
# 2                                                         I K K Wagh Institute of Engineering Education and Research, Nashik
# 3                                                         I K K Wagh Institute of Engineering Education and Research, Nashik
# 4                                         I Jagadamba Education Soc Nashik s S N D College of Engineering Reserch, Babulgaon
# ..                                                                                                                       ...
# 74                                I Shri Someshwar Shikshan Prasarak Mandals, Someshwar Engineering College, Someshwar Nagar
# 75                                                                I Bharati Vidyapeeth s College of Engineering,Lavale, Pune
# 76                                                 I Dr D Y Patil Institute of Engineering, Management Reseach, Akurdi, Pune
# 77                          I Pimpri Chinchwad Education Trust s Pimpri Chinchwad College Of Engineering And Research, Ravet
# 78                                                                 I Dr D Y Patil College Of Engineering Innovation,Talegaon
#
#    Subject_code       Subject_name                   Home University  \
# 0     510819110  Civil Engineering  Savitribai Phule Pune University
# 1     510919110  Civil Engineering  Savitribai Phule Pune University
# 2     512119110  Civil Engineering  Savitribai Phule Pune University
# 3     512119120  Civil Engineering  Savitribai Phule Pune University
# 4     512419110  Civil Engineering  Savitribai Phule Pune University
# ..          ...                ...                               ...
# 74    679519110  Civil Engineering  Savitribai Phule Pune University
# 75    679619110  Civil Engineering  Savitribai Phule Pune University
# 76    680219110  Civil Engineering  Savitribai Phule Pune University
# 77    682219110  Civil Engineering  Savitribai Phule Pune University
# 78    683419110  Civil Engineering  Savitribai Phule Pune University
#
#     Cateogry   Rank       Score
# 0     GOPENO  52859  51.2825619
# 1       TFWS  22507  88.4145767
# 2       TFWS  38384  73.4587169
# 3        EWS  69033  24.6695828
# 4        EWS  47856  59.9932649
# ..       ...    ...         ...
# 74    GOPENH  85941   2.7204652
# 75    LOPENO  79466  13.2999718
# 76    GOPENO  52645  51.6866667
# 77      TFWS  43469  66.6548380
# 78  DEFOPENS  16178  92.1746341
#
# [79 rows x 8 columns]

# %%
#required_cate=["GOPENH","GOPENS"]

# %%
#data_02[(data_02["Cateogry"]=="GOPENH") & (data_02["Cateogry"]=="GOPENS")]

# %%
gopenh=data_02.index[data_02["Cateogry"]=="GOPENH"].tolist()
print(gopenh)
gopens=data_02.index[data_02["Cateogry"]=="GOPENS"].tolist()
print(gopens)
# Out:
# [6, 8, 13, 15, 16, 20, 22, 23, 25, 35, 43, 46, 54, 61, 63, 64, 65, 71, 72, 73, 74]
# [9, 28, 32, 34, 52]

# %%
not_gopens_h=[]
for i in range(0,79):
    if (i not in gopenh) & (i not in gopens):
        not_gopens_h.append(i)

# %%
print(not_gopens_h)
# Out:
# [0, 1, 2, 3, 4, 5, 7, 10, 11, 12, 14, 17, 18, 19, 21, 24, 26, 27, 29, 30, 31, 33, 36, 37, 38, 39, 40, 41, 42, 44, 45, 47, 48, 49, 50, 51, 53, 55, 56, 57, 58, 59, 60, 62, 66, 67, 68, 69, 70, 75, 76, 77, 78]

# %%
data_02.drop(not_gopens_h,inplace=True)

# %%
#data_02["Cateogry"]=="GOPENS"

# %%
data_02.drop(data_02.index[data_02.Rank.isnull()],inplace=True)

data_02["Rank"]=data_02["Rank"].astype(int)

# %%
data_02
# Out:
#    College_code  \
# 6          5139
# 8          5160
# 9          5161
# 13         5177
# 15         5181
# 16         5184
# 20         5382
# 22         5399
# 23         5401
# 25         5411
# 28         6006
# 32         6144
# 34         6149
  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 65    663519110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 71    676919110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 72    678719110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 73    679419110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 74    679519110  Civil Engineering  Savitribai Phule Pune University   GOPENH
#
#      Rank       Score
# 6   59802  38.7118617
# 8   63038  32.9012261
# 9   33509  79.0915609
# 13  72266  21.4280541
# 15  61863  34.9282678
# 16  42056  68.7108478
# 20  62525  33.8311016
# 22  39724  71.8466430
# 23  54056  49.2558823
# 25  84971   4.6301862
# 28   5287  97.5594389
# 32  31092  81.4897562
# 34  13668  93.5151322
# 35  83161   7.7616361
# 43  82426   8.9851756
# 46  52876  51.2525075
# 52  62081  34.5075064
# 54  84840   4.8688108
# 61  84504   5.4572250
# 63  81450  10.5150525
# 64  67425  26.5459905
# 65  81897   9.8234395
# 71  79696  13.0262234
# 72  61907  34.8667106
# 73  60151  38.0521136
# 74  85941   2.7204652

# %%
data_03=data_02.sort_values(by = "Rank",ascending=True).iloc[:11,:]

# %%
data_03.reset_index(drop=True,inplace=True)

# %%
data_03
# Out:
#    College_code  \
# 0          6006
# 1          6149
# 2          6144
# 3          5161
# 4          5399
# 5          5184
# 6          6203
# 7          5401
# 8          5139
# 9          6794
# 10         5181
#
#                                                                                                      College_name  \
# 0                                                                                  I College of Engineering, Pune
# 1                             I Choudhary Attar Singh Yadav Memorial Trust,Siddhant College of Engineering, Maval
# 2                                              I Genba Sopanrao Moze College of Engineering, Baner Balewadi, Pune
# 3                                                   I Dr Vithalrao Vikhe Patil College of Engineering, Ahmednagar
# 4                                                             I Sanghavi College of Engineering, Varvandi, Nashik
# 5   I Amruta Vaishnavi Education Welfare Trust s Shatabdi Institute of Engineering Research, Agaskhind Tal Sinnar
# 6                                              I Marathwada Mitra Mandal s Institute of Technology, Lohgaon, Pune
# 7                              I Jawahar Education Society s Institute of Technology, Management Research, Nashik
# 8                                          I Pravara Rural College of Engineering, Loni, Pravaranagar, Ahmednagar
# 9                                                          I Anantrao Pawar College of Engineering Research, Pune
# 10       I Gokhale Education Society s, R H Sapat College of Engineering, Management Studies and Research, Nashik
#
#    Subject_code       Subject_name                   Home University Cateogry  \
# 0     600619110  Civil Engineering  Savitribai Phule Pune University   GOPENS
# 1     614919110  Civil Engineering  Savitribai Phule Pune University   GOPENS
# 2     614419110  Civil Engineering  Savitribai Phule Pune University   GOPENS
# 3     516119110  Civil Engineering  Savitribai Phule Pune University   GOPENS
# 4     539919110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 5     518419110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 6     620319110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 7     540119110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 8     513919110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 9     679419110  Civil Engineering  Savitribai Phule Pune University   GOPENH
# 10    518119110  Civil Engineering  Savitribai Phule Pune University   GOPENH
#
#      Rank       Score
# 0    5287  97.5594389
# 1   13668  93.5151322
# 2   31092  81.4897562
# 3   33509  79.0915609
# 4   39724  71.8466430
# 5   42056  68.7108478
# 6   52876  51.2525075
# 7   54056  49.2558823
# 8   59802  38.7118617
# 9   60151  38.0521136
# 10  61863  34.9282678

# %% [markdown]
# # Submission file

# %%
data_03.to_csv(r"Top_10_civil_clg_of_savitribai.csv",index=False)
